# %%
import numpy as np
np.set_printoptions(threshold=np.inf)
import matplotlib.pyplot as plt
import pandas as pd

#Importing the dataset
dataset = pd.read_csv('bank.csv')

# %%
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# RowNumber          10000 non-null int64
# CustomerId         10000 non-null int64
# Surname            10000 non-null object
# CreditScore        10000 non-null int64
# Geography          10000 non-null object
# Gender             10000 non-null object
# Age                10000 non-null int64
# Tenure             10000 non-null int64
# Balance            10000 non-null float64
# NumOfProducts      10000 non-null int64
# HasCrCard          10000 non-null int64
# IsActiveMember     10000 non-null int64
# EstimatedSalary    10000 non-null float64
# Exited             10000 non-null int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
# there are no missing vallues
# gender and geography are  categorical variables


#drop RowNumber and CustomerId as they have no value to the prediction

dataset.drop(['RowNumber', 'CustomerId', 'Surname'], axis = 1)
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
 ## Identify Target variable
    # The "Exited" column is the target variable while the othesr are features

# %%
# Train and Test Data Split

# %%
X = dataset.iloc[:, 3:13].values
y = dataset.iloc[:, 13].values

# %%
print(X[:10,:], '\n')
print(y[:10])
# Out:
# [[619 'France' 'Female' 42 2 0.0 1 1 1 101348.88]
#  [608 'Spain' 'Female' 41 1 83807.86 1 0 1 112542.58]
#  [502 'France' 'Female' 42 8 159660.8 3 1 0 113931.57]
#  [699 'France' 'Female' 39 1 0.0 2 0 0 93826.63]
#  [850 'Spain' 'Female' 43 2 125510.82 1 1 1 79084.1]
#  [645 'Spain' 'Male' 44 8 113755.78 2 1 0 149756.71]
#  [822 'France' 'Male' 50 7 0.0 2 1 1 10062.8]
#  [376 'Germany' 'Female' 29 4 115046.74 4 1 0 119346.88]
#  [501 'France' 'Male' 44 4 142051.07 2 0 1 74940.5]
#  [684 'France' 'Male' 27 2 134603.88 1 1 1 71725.73]]
#
# [1 0 1 0 0 1 0 1 0 0]

# %%
# To Treat the Categorical Variables we have to encode
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

labelencoder_X = LabelEncoder()
X[:, 1] = labelencoder_X.fit_transform(X[:, 1]) #Geography

labelencoder_X_2 = LabelEncoder()
X[:, 2] = labelencoder_X_2.fit_transform(X[:, 2]) #Gender

print(X[:10,:], '\n')
print(y[:10])
# Out:
# [[619 0 0 42 2 0.0 1 1 1 101348.88]
#  [608 2 0 41 1 83807.86 1 0 1 112542.58]
#  [502 0 0 42 8 159660.8 3 1 0 113931.57]
#  [699 0 0 39 1 0.0 2 0 0 93826.63]
#  [850 2 0 43 2 125510.82 1 1 1 79084.1]
#  [645 2 1 44 8 113755.78 2 1 0 149756.71]
#  [822 0 1 50 7 0.0 2 1 1 10062.8]
#  [376 1 0 29 4 115046.74 4 1 0 119346.88]
#  [501 0 1 44 4 142051.07 2 0 1 74940.5]
#  [684 0 1 27 2 134603.88 1 1 1 71725.73]]
#
# [1 0 1 0 0 1 0 1 0 0]

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# Feature Scaling 
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
## Creating the Newural Network

import keras
import sys
from keras.models import Sequential # initialize NN
from keras.layers import Dense # create layers in NN

#Initialising the ANN 
classifier = Sequential()

#Input Layer
classifier.add(Dense(units = 6, kernel_initializer = "uniform", activation = 'relu', input_dim = 10 ))

# Adding Second hidden layer
classifier.add(Dense(units = 6, kernel_initializer = "uniform", activation = "relu"))

# Adding Output Layer
classifier.add(Dense(units = 1, kernel_initializer = "uniform", activation = "sigmoid"))

# Use Gradient Descent
classifier.compile(optimizer = "adam",loss= "binary_crossentropy",metrics=["accuracy"])

# Fit the Neural Network to the training set
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100  )
# Out:
# Epoch 1/100
# 800/800 [==============================] - 0s 568us/step - loss: 0.4879 - accuracy: 0.7961
# Epoch 2/100
# 800/800 [==============================] - 0s 544us/step - loss: 0.4355 - accuracy: 0.7960
# Epoch 3/100
# 800/800 [==============================] - 0s 574us/step - loss: 0.4337 - accuracy: 0.7960
# Epoch 4/100
# 800/800 [==============================] - 0s 531us/step - loss: 0.4311 - accuracy: 0.7960
# Epoch 5/100
# 800/800 [==============================] - 1s 708us/step - loss: 0.4267 - accuracy: 0.7989
# Epoch 6/100
# 800/800 [==============================] - 0s 598us/step - loss: 0.4228 - accuracy: 0.8206
# Epoch 7/100
# 800/800 [==============================] - 0s 558us/step - loss: 0.4199 - accuracy: 0.8242
# Epoch 8/100
# 800/800 [==============================] - 0s 554us/step - loss: 0.4184 - accuracy: 0.8264
# Epoch 9/100
# 800/800 [==============================] - 0s 515us/step - loss: 0.4161 - accuracy: 0.8291
# Epoch 10/100
# ...

# %%
# 100 epochs on the training set, returned an accuracy of around 83%

#Prediction

#Predicting the Test set results at 0.5 threshold
y_pred = classifier.predict(X_test)
#Threshold of 50%
y_pred = (y_pred > 0.5)
y_pred
# Out:
# array([[False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
# ...

# %%
#

 # Confusion Matrix
from sklearn.metrics import confusion_matrix
conf = confusion_matrix(y_test, y_pred)
conf
# Out:
# array([[1533,   62],
#        [ 258,  147]])

# %%
accuracy = (1533+147)/(2000)
accuracy
# Out:
# 0.84

# %%
# The model was able to predict the probability of clients leaving the bank with an accuracy of 84%

# %%
# Hyperparameter Tuning
# Tuning the ANN
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import Dense

def build_classifier(optimizer):
     classifier = Sequential()
     classifier.add(Dense(units = 6, kernel_initializer = "uniform", activation = "relu", input_dim = 10))
     classifier.add(Dense(units = 6, kernel_initializer = "uniform", activation = "relu"))
     classifier.add(Dense(units = 1, kernel_initializer = "uniform", activation = "sigmoid"))
     classifier.compile(optimizer = optimizer, loss = "binary_crossentropy", metrics = ["accuracy"])
     return classifier
classifier = KerasClassifier(build_fn = build_classifier)
parameters = {'batch_size': [25, 32],'epochs': [100, 500], 'optimizer': ['adam', 'rmsprop']}
grid_search = GridSearchCV(estimator = classifier,
param_grid = parameters, scoring = 'accuracy',cv = 10)
grid_search = grid_search.fit(X_train, y_train)
best_parameters = grid_search.best_params_
best_accuracy = grid_search.best_score_
# Out:
# Epoch 1/100
# 288/288 [==============================] - 0s 731us/step - loss: 0.5597 - accuracy: 0.7951
# Epoch 2/100
# 288/288 [==============================] - 0s 789us/step - loss: 0.4378 - accuracy: 0.7971
# Epoch 3/100
# 288/288 [==============================] - 0s 802us/step - loss: 0.4343 - accuracy: 0.7971
# Epoch 4/100
# 288/288 [==============================] - 0s 816us/step - loss: 0.4317 - accuracy: 0.7971
# Epoch 5/100
# 288/288 [==============================] - 0s 854us/step - loss: 0.4289 - accuracy: 0.7971
# Epoch 6/100
# 288/288 [==============================] - 0s 691us/step - loss: 0.4263 - accuracy: 0.7971
# Epoch 7/100
# 288/288 [==============================] - 0s 510us/step - loss: 0.4239 - accuracy: 0.7971
# Epoch 8/100
# 288/288 [==============================] - 0s 497us/step - loss: 0.4220 - accuracy: 0.8139
# Epoch 9/100
# 288/288 [==============================] - 0s 495us/step - loss: 0.4206 - accuracy: 0.8210
# Epoch 10/100
# ...

# %%
# highest Accuracy is about 0.86 which is very good
